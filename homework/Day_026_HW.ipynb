# %% [markdown]
# # 範例 : 計程車費率預測
# https://www.kaggle.com/c/new-york-city-taxi-fare-prediction

# %% [markdown]
# # [作業目標]
# - 使用並觀察特徵組合, 在計程車費率預測競賽的影響

# %% [markdown]
# # [作業重點]
# - 仿造範例並參考今日課程內容, 使用經緯度一圈的長度比的概念造出新特徵, 觀察有什麼影響 (In[6], Out[6])
# - 只使用上面所造的這個新特徵, 觀察有什麼影響 (In[7], Out[7])

# %%
# 做完特徵工程前的所有準備
import pandas as pd
import numpy as np
import datetime
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import GradientBoostingRegressor

data_path = 'data/'
df = pd.read_csv(data_path + 'taxi_data1.csv')

train_Y = df['fare_amount']
df = df.drop(['fare_amount'] , axis=1)
df.head()
# Out:
#            pickup_datetime  pickup_longitude  pickup_latitude  \
# 0  2011-10-21 23:54:10 UTC        -73.990580        40.761071
# 1  2015-02-03 10:42:03 UTC        -73.988403        40.723431
# 2  2014-03-16 18:58:58 UTC        -74.015785        40.715110
# 3  2009-06-13 16:10:54 UTC        -73.977322        40.787275
# 4  2014-06-12 03:25:56 UTC        -73.989683        40.729717
#
#    dropoff_longitude  dropoff_latitude  passenger_count
# 0         -73.981128         40.758634                2
# 1         -73.989647         40.741695                1
# 2         -74.012029         40.707888                2
# 3         -73.958030         40.778838                3
# 4         -73.982490         40.761887                3

# %%
# 時間特徵分解方式:使用datetime
df['pickup_datetime'] = df['pickup_datetime'].apply(lambda x: datetime.datetime.strptime(x, '%Y-%m-%d %H:%M:%S UTC'))
df['pickup_year'] = df['pickup_datetime'].apply(lambda x: datetime.datetime.strftime(x, '%Y')).astype('int64')
df['pickup_month'] = df['pickup_datetime'].apply(lambda x: datetime.datetime.strftime(x, '%m')).astype('int64')
df['pickup_day'] = df['pickup_datetime'].apply(lambda x: datetime.datetime.strftime(x, '%d')).astype('int64')
df['pickup_hour'] = df['pickup_datetime'].apply(lambda x: datetime.datetime.strftime(x, '%H')).astype('int64')
df['pickup_minute'] = df['pickup_datetime'].apply(lambda x: datetime.datetime.strftime(x, '%M')).astype('int64')
df['pickup_second'] = df['pickup_datetime'].apply(lambda x: datetime.datetime.strftime(x, '%S')).astype('int64')
df.head()
# Out:
#       pickup_datetime  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0 2011-10-21 23:54:10        -73.990580        40.761071         -73.981128
# 1 2015-02-03 10:42:03        -73.988403        40.723431         -73.989647
# 2 2014-03-16 18:58:58        -74.015785        40.715110         -74.012029
# 3 2009-06-13 16:10:54        -73.977322        40.787275         -73.958030
# 4 2014-06-12 03:25:56        -73.989683        40.729717         -73.982490
#
#    dropoff_latitude  passenger_count  pickup_year  pickup_month  pickup_day  \
# 0         40.758634                2         2011            10          21
# 1         40.741695                1         2015             2           3
# 2         40.707888                2         2014             3          16
# 3         40.778838                3         2009             6          13
# 4         40.761887                3         2014             6          12
#
#    pickup_hour  pickup_minute  pickup_second
# 0           23             54             10
# 1           10             42              3
# 2           18             58             58
# 3           16             10             54
# 4            3             25             56

# %%
# 將結果使用線性迴歸 / 梯度提升樹分別看結果
df = df.drop(['pickup_datetime'] , axis=1)
scaler = MinMaxScaler()
train_X = scaler.fit_transform(df)
Linear = LinearRegression()
print(f'Linear Reg Score : {cross_val_score(Linear, train_X, train_Y, cv=5).mean()}')
GDBT = GradientBoostingRegressor()
print(f'Gradient Boosting Reg Score : {cross_val_score(GDBT, train_X, train_Y, cv=5).mean()}')
# Out:
# C:\Users\leo\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:323: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
# Linear Reg Score : 0.026876871475641616
# Gradient Boosting Reg Score : 0.7107998357660751

# %%
# 增加緯度差, 經度差, 座標距離等三個特徵
df['longitude_diff'] = df['dropoff_longitude'] - df['pickup_longitude']
df['latitude_diff'] = df['dropoff_latitude'] - df['pickup_latitude']
df['distance_2D'] = (df['longitude_diff']**2 + df['latitude_diff']**2)**0.5
df[['distance_2D', 'longitude_diff', 'latitude_diff', 'pickup_longitude', 'pickup_latitude', 'dropoff_longitude', 'dropoff_latitude']].head()
# Out:
#    distance_2D  longitude_diff  latitude_diff  pickup_longitude  \
# 0     0.009761        0.009452      -0.002437        -73.990580
# 1     0.018307       -0.001244       0.018265        -73.988403
# 2     0.008140        0.003756      -0.007222        -74.015785
# 3     0.021056        0.019292      -0.008437        -73.977322
# 4     0.032964        0.007193       0.032170        -73.989683
#
#    pickup_latitude  dropoff_longitude  dropoff_latitude
# 0        40.761071         -73.981128         40.758634
# 1        40.723431         -73.989647         40.741695
# 2        40.715110         -74.012029         40.707888
# 3        40.787275         -73.958030         40.778838
# 4        40.729717         -73.982490         40.761887

# %%
# 結果 : 準確度上升
train_X = scaler.fit_transform(df)
print(f'Linear Reg Score : {cross_val_score(Linear, train_X, train_Y, cv=5).mean()}')
print(f'Gradient Boosting Reg Score : {cross_val_score(GDBT, train_X, train_Y, cv=5).mean()}')
# Out:
# C:\Users\leo\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:323: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
# Linear Reg Score : 0.027479693774541868
# Gradient Boosting Reg Score : 0.8046908809458259

# %% [markdown]
# # 作業1
# * 參考今日教材，試著使用經緯度一圈的長度比這一概念，組合出一個新特徵，再觀察原特徵加上新特徵是否提升了正確率?

# %%
df[['pickup_longitude', 'pickup_latitude', 'dropoff_longitude', 'dropoff_latitude']].describe()
# Out:
#        pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude
# count       5000.000000      5000.000000        5000.000000       5000.000000
# mean         -72.635174        39.981148         -72.619979         39.972626
# std           10.013060         5.989760          10.065420          6.016378
# min          -82.325968       -73.999735         -82.299888        -74.002015
# 25%          -73.992029        40.735483         -73.991756         40.733386
# 50%          -73.981477        40.752824         -73.979938         40.752687
# 75%          -73.966317        40.767127         -73.963018         40.767461
# max           40.763382        41.366138          40.755657         41.366138

# %%
def np_getDistance(A , B , C , D):# 先緯度後經度
    ra = 6378140  # radius of equator: meter
    rb = 6356755  # radius of polar: meter
    flatten = 0.003353 # Partial rate of the earth
    # change angle to radians
    
    radLatA = np.radians(A)
    radLonA = np.radians(B)
    radLatB = np.radians(C)
    radLonB = np.radians(D)
 
    pA = np.arctan(rb / ra * np.tan(radLatA))
    pB = np.arctan(rb / ra * np.tan(radLatB))
    
    x = np.arccos( np.multiply(np.sin(pA),np.sin(pB)) + np.multiply(np.multiply(np.cos(pA),np.cos(pB)),np.cos(radLonA - radLonB)))
    c1 = np.multiply((np.sin(x) - x) , np.power((np.sin(pA) + np.sin(pB)),2)) / np.power(np.cos(x / 2),2)
    c2 = np.multiply((np.sin(x) + x) , np.power((np.sin(pA) - np.sin(pB)),2)) / np.power(np.sin(x / 2),2)
    dr = flatten / 8 * (c1 - c2)
    distance = 0.001 * ra * (x + dr)
    return distance

# %%
df['distance_real'] = np_getDistance(df['pickup_latitude'],df['pickup_longitude'],df['dropoff_latitude'],df['dropoff_longitude'])
df.head()
# Out:
# C:\Users\leo\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in arccos
#   from ipykernel import kernelapp as app
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 0        -73.990580        40.761071         -73.981128         40.758634
# 1        -73.988403        40.723431         -73.989647         40.741695
# 2        -74.015785        40.715110         -74.012029         40.707888
# 3        -73.977322        40.787275         -73.958030         40.778838
# 4        -73.989683        40.729717         -73.982490         40.761887
#
#    passenger_count  pickup_year  pickup_month  pickup_day  pickup_hour  \
# 0                2         2011            10          21           23
# 1                1         2015             2           3           10
# 2                2         2014             3          16           18
# 3                3         2009             6          13           16
# 4                3         2014             6          12            3
#
#    pickup_minute  pickup_second  longitude_diff  latitude_diff  distance_2D  \
# 0             54             10        0.009452      -0.002437     0.009761
# 1             42              3       -0.001244       0.018265     0.018307
# 2             58             58        0.003756      -0.007222     0.008140
# 3             10             54        0.019292      -0.008437     0.021056
# 4             25             56        0.007193       0.032170     0.032964
#
#    distance_real
# 0       0.842759
# 1       2.030996
# 2       0.862509
# 3       1.878741
# 4       3.623728

# %%
# 檢查是否有缺失值 : 是
np.isnan(df).any()
# Out:
# pickup_longitude     False
# pickup_latitude      False
# dropoff_longitude    False
# dropoff_latitude     False
# passenger_count      False
# pickup_year          False
# pickup_month         False
# pickup_day           False
# pickup_hour          False
# pickup_minute        False
# pickup_second        False
# longitude_diff       False
# latitude_diff        False
# distance_2D          False
# distance_real         True
# dtype: bool

# %%
print(df[df['distance_real'].isnull()].shape)
df[df['distance_real'].isnull()]
# Out:
# (133, 15)
#       pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 30          -73.956138        40.778872         -73.956138         40.778872
# 98            0.000000         0.000000           0.000000          0.000000
# 100         -73.975015        40.762672         -73.975015         40.762672
# 122         -73.978307        40.764860         -73.978307         40.764860
# 131           0.000000         0.000000           0.000000          0.000000
# 165           0.000000         0.000000           0.000000          0.000000
# 171           0.000000         0.000000           0.000000          0.000000
# 209         -74.003662        40.740162         -74.003662         40.740162
# 224         -74.015805        40.718032         -74.015805         40.718032
# 301         -74.006362        40.706027         -74.006362         40.706027
# 377           0.000000         0.000000           0.000000          0.000000
# 517         -73.995047        40.760068         -73.995047         40.760068
# 536           0.000000         0.000000           0.000000          0.000000
# 681         -73.783792        40.666823         -73.783792         40.666823
# 744           0.000000         0.000000           0.000000          0.000000
# 786           0.000000         0.000000           0.000000          0.000000
# 851         -74.010112        40.735960         -74.010112         40.735960
# 860           0.000000         0.000000           0.000000          0.000000
# 872           0.000000         0.000000           0.000000          0.000000
# 882           0.000000         0.000000           0.000000          0.000000
# 906           0.000000         0.000000           0.000000          0.000000
# 910           0.000000         0.000000           0.000000          0.000000
# 975           0.000000         0.000000           0.000000          0.000000
# 976           0.000000         0.000000           0.000000          0.000000
# 1028          0.000000         0.000000           0.000000          0.000000
# 1053        -73.995608        40.741375         -73.995608         40.741375
# 1083          0.000000         0.000000           0.000000          0.000000
# 1089        -73.988945        40.748402         -73.988945         40.748402
# 1140          0.000000         0.000000           0.000000          0.000000
# 1169          0.000000         0.000000           0.000000          0.000000
# ...                ...              ...                ...               ...
# 4266        -73.981245        40.753765         -73.981245         40.753765
# 4270          0.000000         0.000000           0.000000          0.000000
# 4363        -73.977367        40.776862         -73.977367         40.776862
# 4368          0.000000         0.000000           0.000000          0.000000
# 4387        -73.993692        40.734277         -73.993692         40.734277
# 4451          0.000000         0.000000           0.000000          0.000000
# 4487        -74.009092        40.710568         -74.009092         40.710568
# 4570          0.000000         0.000000           0.000000          0.000000
# 4571          0.000000         0.000000           0.000000          0.000000
# 4577        -73.943240        40.777675         -73.943240         40.777675
# 4581        -73.973372        40.757372         -73.973372         40.757372
# 4588        -73.983549        40.738224         -73.983549         40.738224
# 4596        -73.790018        40.646913         -73.790018         40.646913
# 4640          0.000000         0.000000           0.000000          0.000000
# 4649        -73.912125        40.777170         -73.912125         40.777170
# 4656          0.000000         0.000000           0.000000          0.000000
# 4658          0.000000         0.000000           0.000000          0.000000
# 4676          0.000000         0.000000           0.000000          0.000000
# 4678          0.000000         0.000000           0.000000          0.000000
# 4686          0.000000         0.000000           0.000000          0.000000
# 4713        -73.971748        40.759926         -73.971748         40.759926
# 4714          0.000000         0.000000           0.000000          0.000000
# 4820        -73.965700        40.759667         -73.965700         40.759667
# 4841          0.000000         0.000000           0.000000          0.000000
# 4850          0.000000         0.000000           0.000000          0.000000
# 4854        -73.980257        40.762168         -73.980257         40.762168
# 4885          0.000000         0.000000           0.000000          0.000000
# 4932        -73.944860        40.810917         -73.944860         40.810917
# 4951          0.000000         0.000000           0.000000          0.000000
# 4989        -73.965067        40.755190         -73.965067         40.755190
#
#       passenger_count  pickup_year  pickup_month  pickup_day  pickup_hour  \
# 30                  1         2012             2          16           20
# 98                  1         2009             9          21            7
# 100                 2         2014             2          17           18
# 122                 2         2009             7          28           10
# 131                 1         2011             6          30            6
# 165                 1         2009            12          11           12
# 171                 1         2015             1          31            0
# 209                 1         2010             1          24           18
# 224                 5         2010             5          20           16
# 301                 1         2014             2          19           21
# 377                 1         2013            12          17           23
# 517                 1         2011            10          19           12
# 536                 1         2013             5          18            7
# 681                 1         2012             6           1           10
# 744                 1         2009            12          29           21
# 786                 1         2009             1          10            0
# 851                 1         2012            12          16           19
# 860                 5         2010            10           9           23
# 872                 5         2011             9           5           11
# 882                 1         2013             8           3           17
# 906                 1         2015             4           9           20
# 910                 1         2009            11          14           18
# 975                 2         2015             1          16           23
# 976                 1         2012             1          25           22
# 1028                1         2011             7          25           11
# 1053                1         2013             3           4           12
# 1083                6         2012             5          12            5
# 1089                1         2015             2           9           10
# 1140                1         2011             1          22            3
# 1169                5         2010             5           6           17
# ...               ...          ...           ...         ...          ...
# 4266                1         2010             8           3           23
# 4270                5         2010             8          17           22
# 4363                2         2011            10           7            0
# 4368                2         2011             7          30            1
# 4387                2         2009             3          12           19
# 4451                5         2012             3          17            2
# 4487                5         2010            10           8           23
# 4570                1         2011             7          28           14
# 4571                2         2010             4          28           19
# 4577                1         2011             2          27           10
# 4581                5         2013            11           1           22
# 4588                1         2014             4          16            6
# 4596                1         2010             9          12            2
# 4640                1         2015             3          12           15
# 4649                1         2010             7           4           14
# 4656                2         2013            12          22            7
# 4658                1         2011             5          12           16
# 4676                1         2015             1          30           21
# 4678                1         2012             7          25           14
# 4686                1         2013             2          16           21
# 4713                1         2013             6          15           12
# 4714                1         2010             5          26            9
# 4820                2         2009            10          29           19
# 4841                4         2010             6          23           10
# 4850                1         2010            12           7           15
# 4854                1         2009             9           3           13
# 4885                1         2010            10          20           14
# 4932                1         2013             7           8           21
# 4951                1         2012             1          18           11
# 4989                5         2013            12          24           18
#
#       pickup_minute  pickup_second  longitude_diff  latitude_diff  \
# 30                5              0             0.0            0.0
# 98               45              0             0.0            0.0
# 100              38              0             0.0            0.0
# 122              58              0             0.0            0.0
# 131              52             36             0.0            0.0
# 165               0             40             0.0            0.0
# 171               8             25             0.0            0.0
# 209              59              0             0.0            0.0
# 224              14              0             0.0            0.0
# 301              41             19             0.0            0.0
# 377              43             54             0.0            0.0
# 517              20              0             0.0            0.0
# 536              15              5             0.0            0.0
# 681              38              0             0.0            0.0
# 744              18              0             0.0            0.0
# 786               6             10             0.0            0.0
# 851               5              0             0.0            0.0
# 860              22              0             0.0            0.0
# 872               7              0             0.0            0.0
# 882              27             21             0.0            0.0
# 906              25              0             0.0            0.0
# 910              23              0             0.0            0.0
# 975              21             47             0.0            0.0
# 976              34              0             0.0            0.0
# 1028             56              0             0.0            0.0
# 1053             43              0             0.0            0.0
# 1083             46              0             0.0            0.0
# 1089              6             11             0.0            0.0
# 1140             16             19             0.0            0.0
# 1169             48              0             0.0            0.0
# ...             ...            ...             ...            ...
# 4266             39              0             0.0            0.0
# 4270             19              0             0.0            0.0
# 4363              5              0             0.0            0.0
# 4368             36              5             0.0            0.0
# 4387             19              0             0.0            0.0
# 4451              4              0             0.0            0.0
# 4487             37              0             0.0            0.0
# 4570             14              0             0.0            0.0
# 4571              3              0             0.0            0.0
# 4577             18              0             0.0            0.0
# 4581             36              0             0.0            0.0
# 4588             51             20             0.0            0.0
# 4596              2              0             0.0            0.0
# 4640             45             54             0.0            0.0
# 4649             40              0             0.0            0.0
# 4656             25              6             0.0            0.0
# 4658             26              0             0.0            0.0
# 4676              7             27             0.0            0.0
# 4678             36              0             0.0            0.0
# 4686             59              0             0.0            0.0
# 4713             14             59             0.0            0.0
# 4714             24             51             0.0            0.0
# 4820             35             32             0.0            0.0
# 4841             20              0             0.0            0.0
# 4850             23              0             0.0            0.0
# 4854             12              0             0.0            0.0
# 4885             40              0             0.0            0.0
# 4932             22             50             0.0            0.0
# 4951             30              0             0.0            0.0
# 4989             36              0             0.0            0.0
#
#       distance_2D  distance_real
# 30            0.0            NaN
# 98            0.0            NaN
# 100           0.0            NaN
# 122           0.0            NaN
# 131           0.0            NaN
# 165           0.0            NaN
# 171           0.0            NaN
# 209           0.0            NaN
# 224           0.0            NaN
# 301           0.0            NaN
# 377           0.0            NaN
# 517           0.0            NaN
# 536           0.0            NaN
# 681           0.0            NaN
# 744           0.0            NaN
# 786           0.0            NaN
# 851           0.0            NaN
# 860           0.0            NaN
# 872           0.0            NaN
# 882           0.0            NaN
# 906           0.0            NaN
# 910           0.0            NaN
# 975           0.0            NaN
# 976           0.0            NaN
# 1028          0.0            NaN
# 1053          0.0            NaN
# 1083          0.0            NaN
# 1089          0.0            NaN
# 1140          0.0            NaN
# 1169          0.0            NaN
# ...           ...            ...
# 4266          0.0            NaN
# 4270          0.0            NaN
# 4363          0.0            NaN
# 4368          0.0            NaN
# 4387          0.0            NaN
# 4451          0.0            NaN
# 4487          0.0            NaN
# 4570          0.0            NaN
# 4571          0.0            NaN
# 4577          0.0            NaN
# 4581          0.0            NaN
# 4588          0.0            NaN
# 4596          0.0            NaN
# 4640          0.0            NaN
# 4649          0.0            NaN
# 4656          0.0            NaN
# 4658          0.0            NaN
# 4676          0.0            NaN
# 4678          0.0            NaN
# 4686          0.0            NaN
# 4713          0.0            NaN
# 4714          0.0            NaN
# 4820          0.0            NaN
# 4841          0.0            NaN
# 4850          0.0            NaN
# 4854          0.0            NaN
# 4885          0.0            NaN
# 4932          0.0            NaN
# 4951          0.0            NaN
# 4989          0.0            NaN
#
# [133 rows x 15 columns]

# %%
df['distance_real'] = np.where( ((df['distance_real'].isnull()) & (df['distance_2D'] == 0)), 0, df['distance_real']) 
print(df[df['distance_real'].isnull()].shape)
df[df['distance_real'].isnull()]
# Out:
# (0, 15)
# Empty DataFrame
# Columns: [pickup_longitude, pickup_latitude, dropoff_longitude, dropoff_latitude, passenger_count, pickup_year, pickup_month, pickup_day, pickup_hour, pickup_minute, pickup_second, longitude_diff, latitude_diff, distance_2D, distance_real]
# Index: []

# %%
# 檢查是否有缺失值 : 否
np.isnan(df).any()
# Out:
# pickup_longitude     False
# pickup_latitude      False
# dropoff_longitude    False
# dropoff_latitude     False
# passenger_count      False
# pickup_year          False
# pickup_month         False
# pickup_day           False
# pickup_hour          False
# pickup_minute        False
# pickup_second        False
# longitude_diff       False
# latitude_diff        False
# distance_2D          False
# distance_real        False
# dtype: bool

# %%
import math
"""
Your Code Here, set new character at df['distance_real']
"""
# 觀察結果 
train_X = scaler.fit_transform(df)
print(f'Linear Reg Score : {cross_val_score(Linear, train_X, train_Y, cv=5).mean()}')
print(f'Gradient Boosting Reg Score : {cross_val_score(GDBT, train_X, train_Y, cv=5).mean()}')
# Out:
# C:\Users\leo\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:323: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
# Linear Reg Score : 0.3681083346622744
# Gradient Boosting Reg Score : 0.8023268644244086

# %% [markdown]
# # 作業2
# * 試著只使用新特徵估計目標值(忽略原特徵)，效果跟作業1的結果比較起來效果如何?

# %%
train_X = scaler.fit_transform(df[['distance_real']])
print(f'Linear Reg Score : {cross_val_score(Linear, train_X, train_Y, cv=5).mean()}')
print(f'Gradient Boosting Reg Score : {cross_val_score(GDBT, train_X, train_Y, cv=5).mean()}')
# 結果還較差
# Out:
# Linear Reg Score : 0.001156236904454966
# Gradient Boosting Reg Score : 0.718897093621444
