# %% [markdown]
# ## 作業一
#
# ### [Dataset : Google Play Store Apps](https://www.kaggle.com/lava18/google-play-store-apps#googleplaystore.csv)
#
# ### 1. 你選的這組資料為何重要
# Google Play 是 Android App 的重要平台，內含的資料非常有價值，惟其頁面動態呈現的方式讓爬取資料難度提升，想獲取資料十分不容易
#
# ### 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# Lavanya Gupta，一名 HSBC 的 SE 以網頁爬蟲的方式蒐集而得
#
# ### 3. 蒐集而來的資料型態為何
# 為 CSV 格式的結構化資料，有 13 個欄位，欄位型態多為類別資料
#
# ### 4. 這組資料想解決的問題如何評估
# 可以從 App 的多維度變數找出"高下載量 App 的關鍵因子"，可能是 Name 要包含哪些關鍵字，或是 App 程式大小最好別超過多少 M ... 等
#
# ***
#
# ## 作業二
#
# ### 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# ### 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 提升業績。假設「顧客願意給高評價，代表顧客與司機相處愉快，對載客率是重要的因素」
#
# ### 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 顧客資料 : App 後台蒐集手機，乘坐後由司機人工輸入乘客的視覺性別年齡 <br>
# 交易資料 : App 後台蒐集 <br>
# 評價資料 : 由乘客乘坐後，自行於 App 回饋 <br>
# 路線資料 : 車上裝載 GPS 系統紀錄 <br>
#
# ### 3. 蒐集而來的資料型態為何
# 交易資料 : 結構化資料，欄位含日期、上車點、下車點、乘車時間、移動距離、交易金額、司機年齡、司機性別、司機其他參數...乘客年齡、乘客性別、乘客評價
#
# ### 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# 蒐集足夠的資料後，評估單趟行程的評價，在司機基本資料與乘客資料交叉比對。<br>
# 分為測試組對照組，乘客叫車時，測試組會根據以往資料演算出最有機會與此乘客合拍的司機，進而派其前往載客；對照組則為隨機派送司機載客。<br>
# 驗證方法為檢驗兩組的平均評價，經過統計檢定後，是否有顯著的差距
#
# ***

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, yp):
    mse = MSE = sum((y - yp)**2) / len(y)
    return mse

def mean_absolute_error(y, yp):
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 194.909
# The Mean absolute error is 11.182
